# %%
# %matplotlib inline

import numpy as np
import pandas as pd

import datetime

# %%
TSC = pd.read_csv("TSC_test.csv")

# %%
TSC.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2000-01-04  69.649002  69.649002  68.475197  69.649002  39.525471
# 1  2000-01-05  69.649002  71.214104  68.866302  71.214104  40.413666
# 2  2000-01-06  70.822899  71.214104  69.649002  69.649002  39.525471
# 3  2000-01-07  67.301300  68.475197  66.518600  67.692497  38.415165
# 4  2000-01-10  69.649002  70.431396  68.475197  70.040199  39.747475
#
#          Volume
# 0  2.006623e+11
# 1  4.024668e+11
# 2  1.975457e+11
# 3  2.352703e+11
# 4  2.761717e+11

# %%
TSC.tail()   #最後5筆
# Out:
#             Date   Open   High    Low  Close  Adj Close      Volume
# 4792  2019-01-24  222.5  222.5  220.5  222.5      222.5  26417924.0
# 4793  2019-01-25  226.5  227.0  225.0  226.0      226.0  46692764.0
# 4794  2019-01-28  229.5  229.5  228.0  229.0      229.0  26026257.0
# 4795  2019-01-29  222.5  225.0  222.0  222.5      222.5  41122520.0
# 4796  2019-01-30  220.5  221.5  220.0  221.0      221.0  44755945.0

# %% [markdown]
# 將日期改成INDEX

# %%
TSC.set_index(pd.to_datetime(TSC["Date"]))
# Out:
#                   Date        Open        High         Low       Close  \
# Date
# 2000-01-04  2000-01-04   69.649002   69.649002   68.475197   69.649002
# 2000-01-05  2000-01-05   69.649002   71.214104   68.866302   71.214104
# 2000-01-06  2000-01-06   70.822899   71.214104   69.649002   69.649002
# 2000-01-07  2000-01-07   67.301300   68.475197   66.518600   67.692497
# 2000-01-10  2000-01-10   69.649002   70.431396   68.475197   70.040199
# ...                ...         ...         ...         ...         ...
# 2019-01-24  2019-01-24  222.500000  222.500000  220.500000  222.500000
# 2019-01-25  2019-01-25  226.500000  227.000000  225.000000  226.000000
# 2019-01-28  2019-01-28  229.500000  229.500000  228.000000  229.000000
# 2019-01-29  2019-01-29  222.500000  225.000000  222.000000  222.500000
# 2019-01-30  2019-01-30  220.500000  221.500000  220.000000  221.000000
#
#              Adj Close        Volume
# Date
# 2000-01-04   39.525471  2.006623e+11
# ...

# %%
tsc = TSC.drop("Date", axis=1)       #axis=0代表列(左右)，axis=1代表行(上下)

# %%
tsc.head()
# Out:
#         Open       High        Low      Close  Adj Close        Volume
# 0  69.649002  69.649002  68.475197  69.649002  39.525471  2.006623e+11
# 1  69.649002  71.214104  68.866302  71.214104  40.413666  4.024668e+11
# 2  70.822899  71.214104  69.649002  69.649002  39.525471  1.975457e+11
# 3  67.301300  68.475197  66.518600  67.692497  38.415165  2.352703e+11
# 4  69.649002  70.431396  68.475197  70.040199  39.747475  2.761717e+11

# %%
tsc.index
# Out:
# RangeIndex(start=0, stop=4797, step=1)

# %%
type(tsc.index[0])
# Out:
# int

# %%
TSC["Adj Close"].plot()
# Out:
# <AxesSubplot:>
